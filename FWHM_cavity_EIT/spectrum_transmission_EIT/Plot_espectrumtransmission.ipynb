# %%
#Gerando os arquivos para cada caso mas omitindo a cada run

#Bibliotecas:
import numpy as np
import pandas as pd
#from qutip import *
import csv 
import latex

from PIL import Image
import matplotlib.image as image
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)

import matplotlib.pyplot as plt 
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": "18",
    "font.serif": ["Times New Roman"]})
import matplotlib
matplotlib.rc('xtick', labelsize=13) 
matplotlib.rc('ytick', labelsize=13)
matplotlib.rc('legend', fontsize=13) 
import matplotlib.gridspec as gridspec
from palettable.colorbrewer.qualitative import Set1_5

# %%
#Importando os arquivos:

CEIT_dados = np.loadtxt("CEIT.dat") 
Delta_list = CEIT_dados[:,0]  #toma as linhas da primeira coluna
CEIT_list = CEIT_dados[:,1]   ##toma as linhas da segunda coluna

dois_niveis_dados = np.loadtxt("atomo_2niveis.dat")
dois_niveis_list = dois_niveis_dados[:,1]

cavidade_vazia_dados = np.loadtxt("cavidade_vazia.dat")
cavidade_vazia_list = cavidade_vazia_dados[:,1]

#Mathematica
M1 = np.loadtxt('CEIT_semiclassical_Nat1_g0_ep01_05kappa.csv', delimiter=',')
M2 = np.loadtxt('CEIT_semiclassical_Nat1_g0_ep01_1kappa.csv', delimiter=',')
M3 = np.loadtxt('CEIT_semiclassical_Nat1_g0_ep01_2kappa.csv', delimiter=',')
M4 = np.loadtxt('CEIT_semiclassical_Nat3_g0_ep01.csv', delimiter=',')
M5 = np.loadtxt('CEIT_semiclassical_Nat1_g01_ep01_05kappa.csv', delimiter=',')
M6 = np.loadtxt('CEIT_semiclassical_Nat1_g1_ep01_05kappa.csv', delimiter=',')
M7 = np.loadtxt('CEIT_semiclassical_Nat1_g5_ep01_05kappa.csv', delimiter=',')
M8 = np.loadtxt('CEIT_semiclassical_Nat1_g10_ep01_05kappa.csv', delimiter=',')

#QuTip
N1 = np.loadtxt('CEIT_quantum_Nat1_g0_ep01_05kappa.csv', delimiter=',')
N2 = np.loadtxt('CEIT_quantum_Nat1_g0_ep01_1kappa.csv', delimiter=',')
N3 = np.loadtxt('CEIT_quantum_Nat1_g0_ep01_2kappa.csv', delimiter=',')
N4 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01_1kappa.csv', delimiter=',')
N5 = np.loadtxt('CEIT_quantum_Nat1_g1_ep01_1kappa.csv', delimiter=',')
N6 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_1kappa.csv', delimiter=',')
N7 = np.loadtxt('CEIT_quantum_Nat1_g10_ep01_1kappa.csv', delimiter=',')
N8 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01_Oc0001.csv', delimiter=',')
N9 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01_Oc05.csv', delimiter=',')
N10 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01_Oc15.csv', delimiter=',')
N11 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01_Oc2.csv', delimiter=',')
N12 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_Oc0001.csv', delimiter=',')
N13 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_Oc05.csv', delimiter=',')
N14 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_Oc15.csv', delimiter=',')
N15 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_Oc2.csv', delimiter=',')

R1 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01.csv', delimiter=',')
R2 = np.loadtxt('CEIT_quantum_Nat1_g1_ep01.csv', delimiter=',')
R3 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01_tlist10100.csv', delimiter=',')
R4 = np.loadtxt('CEIT_quantum_Nat1_g5_ep01.csv', delimiter=',')
R5 = np.loadtxt('CEIT_quantum_Nat1_g10_ep1.csv', delimiter=',')
R5 = np.loadtxt('CEIT_quantum_Nat1_g10_ep01.csv', delimiter=',')
R6 = np.loadtxt('CEIT_quantum_Nat1_g10_ep001.csv', delimiter=',')
R7 = np.loadtxt('CEIT_quantum_Nat1_g10_ep0001.csv', delimiter=',')

R8 = np.loadtxt('CEIT_quantum_Nat2_g10_ep01.csv', delimiter=',')
R9 = np.loadtxt('CEIT_quantum_Nat3_g10_ep01.csv', delimiter=',')
R10 = np.loadtxt('CEIT_quantum_Nat4_g10_ep01.csv', delimiter=',')
R11 = np.loadtxt('CEIT_quantum_Nat5_g10_ep01.csv', delimiter=',')

R12 = np.loadtxt('CEIT_quantum_Nat1_g5_ep0001.csv', delimiter=',')
R13 = np.loadtxt('CEIT_quantum_Nat1_g5_ep001.csv', delimiter=',')
R14 = np.loadtxt('CEIT_quantum_Nat1_g5_ep1.csv', delimiter=',')

R15 = np.loadtxt('CEIT_quantum_Nat2_g5_ep01.csv', delimiter=',')
R16 = np.loadtxt('CEIT_quantum_Nat3_g5_ep01.csv', delimiter=',')
R17 = np.loadtxt('CEIT_quantum_Nat4_g5_ep01.csv', delimiter=',')
R18 = np.loadtxt('CEIT_quantum_Nat5_g5_ep01.csv', delimiter=',')

R19 = np.loadtxt('CEIT_quantum_Nat4_g5_ep01_tlist5000.csv', delimiter=',')

F1 = np.loadtxt('CEIT_quantum_Nat1_g1_ep001.csv', delimiter=',')
F2 = np.loadtxt('CEIT_quantum_Nat1_g1_ep01.csv', delimiter=',')
F3 = np.loadtxt('CEIT_quantum_Nat1_g1_ep05.csv', delimiter=',')
F4 = np.loadtxt('CEIT_quantum_Nat1_g1_ep1.csv', delimiter=',')

F5 = np.loadtxt('CEIT_quantum_Nat1_g01_ep01.csv', delimiter=',')
F6 = np.loadtxt('CEIT_quantum_Nat1_g05_ep01.csv', delimiter=',')
F7 = np.loadtxt('CEIT_quantum_Nat1_g07_ep01.csv', delimiter=',')
F8 = np.loadtxt('CEIT_quantum_Nat1_g1_ep01.csv', delimiter=',')

#test: multiplicando todos os parâmetros por 2 (2*kappa)
O1 = np.loadtxt('CEIT_semiclassical_Nat1_g0_ep01_2vz05kappa.csv', delimiter=',')
O2 = np.loadtxt('CEIT_semiclassical_Nat1_g01_ep01_2vz05kappa.csv', delimiter=',')
O3 = np.loadtxt('CEIT_semiclassical_Nat1_g1_ep01_2vz05kappa.csv', delimiter=',')
O4 = np.loadtxt('CEIT_semiclassical_Nat1_g5_ep01_2vz05kappa.csv', delimiter=',')
O5 = np.loadtxt('CEIT_semiclassical_Nat1_g10_ep01_2vz05kappa.csv', delimiter=',')

#test: Oc=2*kappa
P1 = np.loadtxt('CEIT_semiclassical_Nat1_g0_ep01_1Oc_05kappa.csv', delimiter=',')
P2 = np.loadtxt('CEIT_semiclassical_Nat1_g1_ep01_1Oc_05kappa.csv', delimiter=',')
P3 = np.loadtxt('CEIT_semiclassical_Nat1_g1_ep01_1Oc_05kappa.csv', delimiter=',')
P4 = np.loadtxt('CEIT_semiclassical_Nat1_g5_ep01_1Oc_05kappa.csv', delimiter=',')
P5 = np.loadtxt('CEIT_semiclassical_Nat1_g10_ep01_1Oc_05kappa.csv', delimiter=',')

# epsilon=sqrt{1.0}*kappa Oc = 10*kappa

Z1 = np.loadtxt('CEIT_quantum_Nat1_g1_ep1_Oc10.csv', delimiter=',')
Z2 = np.loadtxt('CEIT_quantum_Nat1_g10_ep1_Oc10.csv', delimiter=',')
Z3 = np.loadtxt('CEIT_quantum_Nat1_g20_ep1_Oc10.csv', delimiter=',')
Z4 = np.loadtxt('CEIT_quantum_Nat1_g50_ep1_Oc10.csv', delimiter=',')


#Integração - Mathematica: 
I1 = np.loadtxt('semiclassical_int_Nat1_g01_ep01_1kappa.csv', delimiter=',')
I2 = np.loadtxt('semiclassical_int_Nat1_g1_ep01_1kappa.csv', delimiter=',')
I3 = np.loadtxt('semiclassical_int_Nat1_g5_ep01_1kappa.csv', delimiter=',')
I4 = np.loadtxt('semiclassical_int_Nat1_g10_ep01_1kappa.csv', delimiter=',')
I5 = np.loadtxt('semiclassical_int_Nat1_g01_ep01_2vsparameters_05kappa.csv', delimiter=',')
I6 = np.loadtxt('semiclassical_int_Nat1_g1_ep01_2vsparameters_05kappa.csv', delimiter=',')
I7 = np.loadtxt('semiclassical_int_Nat1_g5_ep01_2vsparameters_05kappa.csv', delimiter=',')
I8 = np.loadtxt('semiclassical_int_Nat1_g10_ep01_2vsparameters_05kappa.csv', delimiter=',')
I9 = np.loadtxt('semiclassical_int_Nat1_g01_ep01_qutipdef.csv', delimiter=',')
I10 = np.loadtxt('semiclassical_int_Nat1_g1_ep01_qutipdef.csv', delimiter=',')
I11 = np.loadtxt('semiclassical_int_Nat1_g5_ep01_qutipdef.csv', delimiter=',')
I12 = np.loadtxt('semiclassical_int_Nat1_g10_ep01_qutipdef.csv', delimiter=',')

#Integração - MatLab: 
T1 = np.loadtxt('semiclassical_intML_TS_Nat1_g1_ep001_Oc1.csv', delimiter=',')
T2 = np.loadtxt('semiclassical_intML_TS_Nat1_g1_ep01_Oc1.csv', delimiter=',')
T3 = np.loadtxt('semiclassical_intML_TS_Nat1_g1_ep05_Oc1.csv', delimiter=',')
T4 = np.loadtxt('semiclassical_intML_TS_Nat1_g1_ep1_Oc1.csv', delimiter=',')

T5 = np.loadtxt('semiclassical_intML_TS_Nat1_g01_ep01_Oc1.csv', delimiter=',')
T6 = np.loadtxt('semiclassical_intML_TS_Nat1_g05_ep01_Oc1.csv', delimiter=',')
T7 = np.loadtxt('semiclassical_intML_TS_Nat1_g07_ep01_Oc1.csv', delimiter=',')
T8 = np.loadtxt('semiclassical_intML_TS_Nat1_g1_ep01_Oc1.csv', delimiter=',')

T9 = np.loadtxt('semiclassical_intML_Nat1_g5_ep01_Oc0001.csv', delimiter=',')
T10 = np.loadtxt('semiclassical_intML_Nat1_g5_ep01_Oc05.csv', delimiter=',')
T11 = np.loadtxt('semiclassical_intML_Nat1_g5_ep01_Oc15.csv', delimiter=',')
T12 = np.loadtxt('semiclassical_intML_Nat1_g5_ep01_Oc2.csv', delimiter=',')

K1 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep01_Oc1.csv', delimiter=',')
K2 = np.loadtxt('semiclassical_intML_TS_Nat3_g5_ep01_Oc1.csv', delimiter=',')
K3 = np.loadtxt('semiclassical_intML_TS_Nat4_g5_ep01_Oc1.csv', delimiter=',')
K4 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1.csv', delimiter=',')

K5 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep0001_Oc1.csv', delimiter=',')
K6 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep001_Oc1.csv', delimiter=',')
K7 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep1_Oc1.csv', delimiter=',')

L1 = np.loadtxt('semiclassical_intML_TS_Nat2_g5_ep01_Oc1.csv', delimiter=',')
L2 = np.loadtxt('semiclassical_intML_TS_Nat2_g5_ep01_Oc1_tlist10000_points10000.csv', delimiter=',')
L3 = np.loadtxt('semiclassical_intML_TS_Nat2_g5_ep01_Oc1_tlist20000.csv', delimiter=',')
L4 = np.loadtxt('semiclassical_intML_TS_Nat2_g5_ep01_Oc1_tlist30000.csv', delimiter=',')

L5 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1_tlist2100.csv', delimiter=',')
L6 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1_tlist5000.csv', delimiter=',')
L7 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1_tlist8000.csv', delimiter=',')
L8 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1_tlist10000.csv', delimiter=',')
L9 = np.loadtxt('semiclassical_intML_TS_Nat5_g5_ep01_Oc1_tlist20000.csv', delimiter=',')

S1 = np.loadtxt('semiclassical_intML_TS_Nat1_g10_ep0001_Oc1.csv', delimiter=',')
S2 = np.loadtxt('semiclassical_intML_TS_Nat1_g10_ep001_Oc1.csv', delimiter=',')
S3 = np.loadtxt('semiclassical_intML_TS_Nat1_g10_ep01_Oc1.csv', delimiter=',')
S4 = np.loadtxt('semiclassical_intML_TS_Nat1_g10_ep1_Oc1.csv', delimiter=',')

S5 = np.loadtxt('semiclassical_intML_TS_Nat2_g10_ep01_Oc1.csv', delimiter=',')
S6 = np.loadtxt('semiclassical_intML_TS_Nat3_g10_ep01_Oc1.csv', delimiter=',')
S7 = np.loadtxt('semiclassical_intML_TS_Nat4_g10_ep01_Oc1.csv', delimiter=',')
S8 = np.loadtxt('semiclassical_intML_TS_Nat5_g10_ep01_Oc1.csv', delimiter=',')
S9 = np.loadtxt('semiclassical_intML_TS_Nat2_g10_ep01_Oc1_t20000.csv', delimiter=',')

A1 = np.loadtxt('semiclassical_intML_TS_Nat1_g2_ep01_Oc1.csv', delimiter=',')
A2 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep05_Oc1.csv', delimiter=',')
A3 = np.loadtxt('semiclassical_intML_TS_Nat1_g5_ep1_Oc1.csv', delimiter=',')

# %%
#Espectro de transmissão: Variando Oc no semiclássico g=0.1

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(T5[:,0], T5[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(T6[:,0], T6[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(T1[:,0], T1[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.plot(T7[:,0], T7[:,1], color = "blue", linestyle = "-.", linewidth = 1.5)
ax1.plot(T8[:,0], T8[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["$\Omega_C=0.001\kappa$","$\Omega_C=0.5\kappa$", "$\Omega_C=1.0\kappa$","$\Omega_C=1.5\kappa$","$\Omega_C=2.0\kappa$"]) 
plt.title(r'Transmission spectrum semiclassical for 1 atom: $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-0.7,0.7)
plt.ylim(0, 1.05*np.max(T5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_semiclassical_g01_ep01_Ocall.png",format='png', dpi=600)
plt.show()

# %%
#Espectro de transmissão: Variando Oc no semiclássico g=5.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(T9[:,0], T9[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(T10[:,0], T10[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(T3[:,0], T3[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.plot(T11[:,0], T11[:,1], color = "blue", linestyle = "-.", linewidth = 1.5)
ax1.plot(T12[:,0], T12[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["$\Omega_C=0.001\kappa$","$\Omega_C=0.5\kappa$", "$\Omega_C=1.0\kappa$","$\Omega_C=1.5\kappa$","$\Omega_C=2.0\kappa$"]) 
plt.title(r'Transmission spectrum semiclassical for 1 atom: $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-2,2)
plt.ylim(0, 1.05*np.max(T9[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_semiclassical_g5_ep01_Ocall.png",format='png', dpi=600)
plt.show()

# %%
#Espectro de transmissão: Variando Oc no quantum g=0.1

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N8[:,0], N8[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(N9[:,0], N9[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(N4[:,0], N4[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.plot(N10[:,0], N10[:,1], color = "blue", linestyle = "-.", linewidth = 1.5)
ax1.plot(N11[:,0], N11[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["$\Omega_C=0.001\kappa$","$\Omega_C=0.5\kappa$", "$\Omega_C=1.0\kappa$","$\Omega_C=1.5\kappa$","$\Omega_C=2.0\kappa$"]) 
plt.title(r'Transmission spectrum quantum for 1 atom: $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-0.7,0.7)
plt.ylim(0, 1.05*np.max(T5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_quantum_g01_ep01_Ocall.png",format='png', dpi=600)
plt.show()

# %%
#Espectro de transmissão: Variando Oc no quantum g=5.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N12[:,0], N12[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(N13[:,0], N13[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(N6[:,0], N6[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.plot(N14[:,0], N14[:,1], color = "blue", linestyle = "-.", linewidth = 1.5)
ax1.plot(N15[:,0], N15[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["$\Omega_C=0.001\kappa$","$\Omega_C=0.5\kappa$", "$\Omega_C=1.0\kappa$","$\Omega_C=1.5\kappa$","$\Omega_C=2.0\kappa$"]) 
plt.title(r'Transmission spectrum quantum for 1 atom: $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-0.5,0.5)
plt.ylim(0, 1.05*np.max(T12[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_quantum_g5_ep01_Ocall.png",format='png', dpi=600)
plt.show()

# %%
#Espectro de transmissão: Modelo Quântico variando kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N1[:,0], N1[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(N2[:,0], N2[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(N3[:,0], N3[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["Modelo Quântico - $0.5\kappa$", "Modelo Quântico - $1\kappa$","Modelo Quântico - $2.0\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N1[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_quantum_allkappa.png",format='png', dpi=600)
plt.show()

# %%
#Espectro de transmissão: Modelo Semi-clássico variando kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(M1[:,0], M1[:,1], color = "k", linestyle = "-", linewidth = 1.5)
ax1.plot(M2[:,0], M2[:,1], color = "red", linestyle = "--", linewidth = 1.5)
ax1.plot(M3[:,0], M3[:,1], color = "darkslategray", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Semi-Clássico  - $0.5\kappa$", "Modelo Semi-Clássico  - $1\kappa$","Modelo Semi-Clássico - $2.0\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(M1[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_semiclassical_allkappa.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N2[:,0],N2[:,1], color = "red", linewidth = 2)
ax1.plot(M1[:,0], M1[:,1], color = "k", linestyle = "--", linewidth = 1.5)
#ax1.plot(M2[:,0], M2[:,1], color = "darkslategray", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Quântico - $\kappa$", "Modelo Semiclássico - $0.5\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N2[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g0_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=0.1

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N4[:,0],N4[:,1], color = "red", linewidth = 2)
ax1.plot(M5[:,0], M5[:,1], color = "k", linestyle = "--", linewidth = 1.5)
#ax1.plot(M2[:,0], M2[:,1], color = "darkslategray", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Quântico - $\kappa$", "Modelo Semiclássico - $0.5\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N4[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g01_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=1.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N5[:,0],N5[:,1], color = "red", linewidth = 2)
ax1.plot(M6[:,0], M6[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Quântico - $\kappa$", "Modelo Semiclássico - $0.5\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=1.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g1_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=5.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N6[:,0],N6[:,1], color = "red", linewidth = 2)
ax1.plot(M7[:,0], M7[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Quântico - $\kappa$", "Modelo Semiclássico - $0.5\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N6[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g5_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=10.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N7[:,0],N7[:,1], color = "red", linewidth = 2)
ax1.plot(M8[:,0], M8[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
#ax1.legend(["Cavity-EIT", "Two-level atom", "Empty cavity"]) 
ax1.legend(["Modelo Quântico - $\kappa$", "Modelo Semiclássico - $0.5\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=10.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N7[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g10_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=0 e teste para parâmetros=2*kappa ou Oc=2*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N2[:,0],N2[:,1], color = "red",linestyle = "-", linewidth = 2)
ax1.plot(M1[:,0], M1[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.plot(O1[:,0], O1[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.plot(P1[:,0], P1[:,1], color = "blue", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ - $\kappa$", "MSC - $0.5\kappa$","MSC - $0.5\kappa$ and $2\kappa$ parameters","MSC - $0.5\kappa$ and $\Omega_C=2\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N2[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g0_ep01_compare_QSC_tests.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=0.1 e teste para parâmetros=2*kappa ou Oc=2*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N4[:,0],N4[:,1], color = "red",linestyle = "-", linewidth = 2)
ax1.plot(M5[:,0], M5[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.plot(O2[:,0], O2[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
ax1.plot(P2[:,0], P2[:,1], color = "blue", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ - $\kappa$", "MSC - $0.5\kappa$","MSC - $0.5\kappa$ and $2\kappa$ parameters","MSC - $0.5\kappa$ and $\Omega_C=2\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N4[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g01_ep01_compare_QSC_tests.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=1.0 e teste para parâmetros=2*kappa ou Oc=2*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N5[:,0],N5[:,1], color = "red",linestyle = "-", linewidth = 2)
#ax1.plot(M6[:,0], M6[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.plot(O3[:,0], O3[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
#ax1.plot(P3[:,0], P3[:,1], color = "blue", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ - $\kappa$", "MSC - $0.5\kappa$","MSC - $0.5\kappa$ and $2\kappa$ parameters","MSC - $0.5\kappa$ and $\Omega_C=2\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=1.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g1_ep01_compare_QSC_tests.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=5.0 e teste para parâmetros=2*kappa ou Oc=2*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N6[:,0],N6[:,1], color = "red",linestyle = "-", linewidth = 2)
#ax1.plot(M7[:,0], M7[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.plot(O4[:,0], O4[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
#ax1.plot(P4[:,0], P4[:,1], color = "blue", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ - $\kappa$", "MSC - $0.5\kappa$","MSC - $0.5\kappa$ and $2\kappa$ parameters","MSC - $0.5\kappa$ and $\Omega_C=2\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N6[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g5_ep01_compare_QSC_tests.png",format='png', dpi=600)
plt.show()

# %%
#Comparando espectros de cada modelo pelo acoplamento: g=10.0 e teste para parâmetros=2*kappa ou Oc=2*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N7[:,0],N7[:,1], color = "red",linestyle = "-", linewidth = 2)
#ax1.plot(M8[:,0], M8[:,1], color = "k", linestyle = "--", linewidth = 1.5)
ax1.plot(O5[:,0], O5[:,1], color = "green", linestyle = "-.", linewidth = 1.5)
#ax1.plot(P5[:,0], P5[:,1], color = "blue", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ - $\kappa$", "MSC - $0.5\kappa$","MSC - $0.5\kappa$ and $2\kappa$ parameters","MSC - $0.5\kappa$ and $\Omega_C=2\kappa$"]) 
plt.title(r'Transmission spectrum for 1 atom: $g=10.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N7[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g10_ep01_compare_QSC_tests.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros de cada modelo e diferentes softwares pelo acoplamento - g=0.1

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N2[:,0],N2[:,1], color = "k", linewidth = 2)
ax1.plot(I9[:,0], I9[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.plot(T1[:,0], T1[:,1], color = "b", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ (qutip)", "MSC (int mathematica)", "MSC (int matlab)"]) 
plt.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N2[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g01_ep01_compare_int_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros de cada modelo e diferentes softwares pelo acoplamento - g=1.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N5[:,0],N5[:,1], color = "k", linewidth = 2)
ax1.plot(I10[:,0], I10[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.plot(T2[:,0], T2[:,1], color = "b", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ (qutip)", "MSC (int mathematica)", "MSC (int matlab)"]) 
ax1.set_xlabel("$\Delta_P/\kappa$")
plt.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=1.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g1_ep01_compare_int_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros de cada modelo e diferentes softwares pelo acoplamento - g=5.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N6[:,0],N6[:,1], color = "k", linewidth = 2)
ax1.plot(I11[:,0], I11[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.plot(T3[:,0], T3[:,1], color = "b", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ (qutip)", "MSC (int mathematica)", "MSC (int matlab)"]) 
plt.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N6[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g5_ep01_compare_int_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros de cada modelo e diferentes softwares pelo acoplamento - g=10.0

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(N7[:,0],N7[:,1], color = "k", linewidth = 2)
ax1.plot(I12[:,0], I12[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.plot(T4[:,0], T4[:,1], color = "b", linestyle = "-.", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend(["MQ (qutip)", "MSC (int mathematica)", "MSC (int matlab)"]) 
plt.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=10.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-10,10)
plt.ylim(0, 1.05*np.max(N7[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_g10_ep01_compare_int_QSC.png",format='png', dpi=600)
plt.show()

# %%
#PLOT: vary g_0, epsilon=sqrt{0.1}*kappa
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True,figsize=(3*3.54,1.0*4.54))#3*3.54,1.0*4.0


#g=0.1: 
ax1.plot(F5[:,0],F5[:,1], color = "k", linewidth = 2.0)
ax1.plot(T5[:,0], T5[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
#ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
ax1.legend(["Quantum","Semiclassical"],frameon=False,fontsize=13) 
ax1.set_xlim(-5,5)
ax1.set_ylim(0, 1.05*np.max(T5[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax1.set_yticks([0,0.5,1.0])
ax1.set_title(r'$g=0.1\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax1.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax1.label_outer()

#g=0.5: 
ax2.plot(F6[:,0],F6[:,1], color = "k", linewidth = 2)
ax2.plot(T6[:,0], T6[:,1], color = "r", linestyle = "--", linewidth = 1.5)
#ax2.set_xlabel("$\Delta_P/\kappa$")
#ax2.set_ylabel(r'Normalized transmission')
#ax2.legend(["Quantum","Semiclassical"],frameon=False) 
#ax2.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax2.set_xlim(-5,5)
ax2.set_ylim(0, 1.05*np.max(T6[:,1])) 
#ax2.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
ax2.set_title(r'$g=0.5\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax2.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
#ax2.label_outer()

#g=0.7: 
ax3.plot(F7[:,0],F7[:,1], color = "k", linewidth = 2)
ax3.plot(T7[:,0], T7[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax3.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax3.set_ylabel(r'Normalized transmission', fontsize=12)
#ax3.legend(["Quantum","Semiclassical"],frameon=False) 
#ax3.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax3.set_xlim(-5,5)
ax3.set_ylim(0, 1.05*np.max(T7[:,1])) 
#ax3.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax3.set_yticks([0,0.5,1.0])
ax3.set_title(r'$g=0.7\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax3.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax3.label_outer()

#g=1.0: 
ax4.plot(F8[:,0],F8[:,1], color = "k", linewidth = 2)
ax4.plot(T8[:,0], T8[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax4.set_xlim(-5,5)
ax4.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax4.set_ylim(0, 1.05*np.max(T8[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax4.set_yticks([0,0.5,1.0])
ax4.set_title(r'$g=1.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax4.label_outer()
plt.text(-18.7, 0.49, 'Normalized transmission', fontsize=14, rotation='vertical')
plt.text(-16.8, 1.37, '(a)', fontsize=12)
plt.text(-4.8, 1.37, '(b)', fontsize=12)
plt.text(-16.8, 0.12, '(c)', fontsize=12)
plt.text(-4.8, 0.12, '(d)', fontsize=12)

fig.suptitle(r'Transmission spectrum EIT-Cavity for 1 atom with $\varepsilon=\sqrt{0.1}\kappa$ and $\Omega_C=\kappa$',fontsize=18)
fig.savefig("EIT_transmission_Nat1_gall_ep01_compare_QSC.png",format='png', dpi=1200)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:37: SyntaxWarning: invalid escape sequence '\D'
# <>:52: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:37: SyntaxWarning: invalid escape sequence '\D'
# <>:52: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_27914/2367105864.py:8: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_27914/2367105864.py:37: SyntaxWarning: invalid escape sequence '\D'
#   ax3.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
# /tmp/ipykernel_27914/2367105864.py:52: SyntaxWarning: invalid escape sequence '\D'
#   ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)

# %%
#PLOT: vary g_0, epsilon=sqrt{1.0}*kappa
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True,figsize=(3*3.54,1.0*4.54))#3*3.54,1.0*4.0


#g=1.0: 
ax1.plot(Z1[:,0],Z1[:,1], color = "k", linewidth = 2.0)
ax1.set_xlabel("$\Delta_P/\kappa$")
#ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
ax1.legend(["Quantum"],frameon=False,fontsize=13) 
ax1.set_xlim(-5,5)
ax1.set_ylim(0, 1.05*np.max(Z1[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax1.set_yticks([0,0.5,1.0])
ax1.set_title(r'$g=1.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax1.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax1.label_outer()

#g=10.0: 
ax2.plot(Z2[:,0],Z2[:,1], color = "k", linewidth = 2)
#ax2.set_xlabel("$\Delta_P/\kappa$")
#ax2.set_ylabel(r'Normalized transmission')
#ax2.legend(["Quantum","Semiclassical"],frameon=False) 
#ax2.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax2.set_xlim(-5,5)
ax2.set_ylim(0, 1.05*np.max(Z2[:,1])) 
#ax2.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
ax2.set_title(r'$g=10.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax2.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
#ax2.label_outer()

#g=20.0: 
ax3.plot(Z3[:,0],Z3[:,1], color = "k", linewidth = 2)
ax3.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax3.set_ylabel(r'Normalized transmission', fontsize=12)
#ax3.legend(["Quantum","Semiclassical"],frameon=False) 
#ax3.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax3.set_xlim(-5,5)
ax3.set_ylim(0, 1.05*np.max(Z3[:,1])) 
#ax3.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax3.set_yticks([0,0.5,1.0])
ax3.set_title(r'$g=20.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax3.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax3.label_outer()

#g=50.0: 
ax4.plot(Z4[:,0],Z4[:,1], color = "k", linewidth = 2)
ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax4.set_xlim(-5,5)
ax4.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax4.set_ylim(0, 1.05*np.max(Z4[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax4.set_yticks([0,0.5,1.0])
ax4.set_title(r'$g=50.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax4.label_outer()
plt.text(-18.7, 0.49, 'Normalized transmission', fontsize=14, rotation='vertical')
plt.text(-16.8, 1.37, '(a)', fontsize=12)
plt.text(-4.8, 1.37, '(b)', fontsize=12)
plt.text(-16.8, 0.12, '(c)', fontsize=12)
plt.text(-4.8, 0.12, '(d)', fontsize=12)

fig.suptitle(r'Transmission spectrum EIT-Cavity for 1 atom with $\varepsilon=\sqrt{1.0}\kappa$ and $\Omega_C=10.0\kappa$',fontsize=18)
fig.savefig("EIT_transmission_Nat1_gall_ep1_Oc10_compare_QSC.png",format='png', dpi=1200)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:34: SyntaxWarning: invalid escape sequence '\D'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:34: SyntaxWarning: invalid escape sequence '\D'
# <>:48: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_7794/614576245.py:7: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_7794/614576245.py:34: SyntaxWarning: invalid escape sequence '\D'
#   ax3.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
# /tmp/ipykernel_7794/614576245.py:48: SyntaxWarning: invalid escape sequence '\D'
#   ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)

# %%
#PLOT: vary g_0, epsilon=sqrt{1.0}*kappa

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(Z1[:,0],Z1[:,1], color = "k", linewidth = 2)
ax1.plot(Z2[:,0], Z2[:,1], color = "r", linestyle = "--", linewidth = 2)
ax1.plot(Z3[:,0], Z3[:,1], color = "blue", linestyle = "-.", linewidth = 2)
ax1.plot(Z4[:,0], Z4[:,1], color = "green", linestyle = ":", linewidth = 2)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend([r'$g=1.0\kappa$',r'$g=10.0\kappa$',r'$g=20.0\kappa$',r'$g=50.0\kappa$']) 
plt.title(r'Transmission spectrum EIT-Cavity for 1 atom with $\varepsilon=\sqrt{1.0}\kappa$ and $\Omega_C=10.0\kappa$', fontsize=18)
plt.xlim(-1,1)
plt.ylim(0, 1.05*np.max(Z1[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat1_gall_ep1_Oc10.png",format='png', dpi=600)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_7794/1152523140.py:8: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta_P/\kappa$")

# %%
#PLOT: vary epsilon
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True,figsize=(3*3.54,1.0*3.54))


#ep=0.01: 
ax1.plot(F1[:,0],F1[:,1], color = "k",  linewidth = 2.0)
ax1.plot(T1[:,0],T1[:,1], color = "r", linestyle = "--", linewidth = 1.5)

ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
ax1.legend(["Quantum","Semiclassical"],frameon=False,fontsize=13) 
ax1.set_xlim(-5,5)
ax1.set_ylim(0, 1.05*np.max(T1[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax1.set_yticks([0,0.5,1.0])
ax1.set_title(r'$\varepsilon_0=\sqrt{0.01}\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax1.set_xlim(-1,1)
ax1.set_xticks([-1.0,-0.5,0.0,0.5,1.0])
ax1.label_outer()

#ep=0.1: 
ax2.plot(F2[:,0],F2[:,1], color = "k", linewidth = 2)
ax2.plot(T2[:,0],T2[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax2.set_xlabel("$\Delta_P/\kappa$")
ax2.set_ylabel(r'Normalized transmission')
#ax2.legend(["Quantum","Semiclassical"],frameon=False) 
#ax2.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax2.set_xlim(-5,5)
ax2.set_ylim(0, 1.05*np.max(T2[:,1])) 
#ax2.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
ax2.set_title(r'$\varepsilon_0=\sqrt{0.1}\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax2.set_xlim(-1,1)
ax2.set_xticks([-1.0,-0.5,0.0,0.5,1.0])
ax2.label_outer()

#ep=0.5: 
ax3.plot(F3[:,0],F3[:,1], color = "k", linewidth = 2)
ax3.plot(T3[:,0],T3[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax3.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
ax3.set_ylabel(r'Normalized \\ transmission', fontsize=12)
#ax3.legend(["Quantum","Semiclassical"],frameon=False) 
#ax3.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax3.set_xlim(-5,5)
ax3.set_ylim(0, 1.05*np.max(T3[:,1])) 
#ax3.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax3.set_yticks([0,0.5,1.0])
ax3.set_title(r'$\varepsilon_0=\sqrt{0.5}\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax3.set_xlim(-1,1)
ax3.set_xticks([-1.0,-0.5,0.0,0.5,1.0])
ax3.label_outer()

#ep=1.0 
ax4.plot(F4[:,0],F4[:,1], color = "k", linewidth = 2)
ax4.plot(T4[:,0],T4[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax4.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax4.set_xlim(-5,5)
ax4.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax4.set_ylim(0, 1.05*np.max(T4[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax4.set_yticks([0,0.5,1.0])
ax4.set_title(r'$\varepsilon_0=\sqrt{1.0}\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax4.label_outer()

fig.suptitle(r'Transmission spectrum EIT-Cavity for 1 atom with $g=1.0\kappa/\sqrt{N_{at}}$ and $\Omega_C=\kappa$',fontsize=15)
fig.savefig("EIT_transmission_Nat1_g1_epall_compare_QSC.png",format='png', dpi=600)
plt.show()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:40: SyntaxWarning: invalid escape sequence '\D'
# <>:56: SyntaxWarning: invalid escape sequence '\D'
# <>:9: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:40: SyntaxWarning: invalid escape sequence '\D'
# <>:56: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_4548/2425681260.py:9: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_4548/2425681260.py:24: SyntaxWarning: invalid escape sequence '\D'
#   ax2.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_4548/2425681260.py:40: SyntaxWarning: invalid escape sequence '\D'
#   ax3.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
# /tmp/ipykernel_4548/2425681260.py:56: SyntaxWarning: invalid escape sequence '\D'
#   ax4.set_xlabel("$\Delta_P/\kappa$",fontsize=13)

# %%
#PLOT: vary Nat
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2, sharex=True,figsize=(3*3.54,1.0*3.54))


#Nat=1: 
ax1.plot(R3[:,0],R3[:,1], color = "k",  linewidth = 2.0)
ax1.plot(K1[:,0],K1[:,1], color = "r", linestyle = "--", linewidth = 1.5)

ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
ax1.legend(["Quantum","Semiclassical"],frameon=False,fontsize=10) 
ax1.set_xlim(-1,1)
ax1.set_ylim(0, 1.05*np.max(R3[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax1.set_yticks([0,0.5,1.0])
ax1.set_title(r'$N_{at}=1$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax1.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax1.label_outer()

#Nat=2: 
ax2.plot(R15[:,0],R15[:,1], color = "k", linewidth = 2)
ax2.plot(L1[:,0],L1[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax2.set_xlabel("$\Delta_P/\kappa$")
ax2.set_ylabel(r'Normalized transmission')
#ax2.legend(["Quantum","Semiclassical"],frameon=False) 
#ax2.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax2.set_xlim(-1,1)
ax2.set_ylim(0, 1.05*np.max(R15[:,1])) 
#ax2.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
ax2.set_title(r'$N_{at}=2$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax2.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax2.label_outer()

#Nat=3:  
ax3.plot(R16[:,0],R16[:,1], color = "k", linewidth = 2)
ax3.plot(K2[:,0],K2[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax3.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
#ax3.set_ylabel(r'Normalized \\ transmission', fontsize=12)
#ax3.legend(["Quantum","Semiclassical"],frameon=False) 
#ax3.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax3.set_xlim(-1,1)
ax3.set_ylim(0, 1.05*np.max(R16[:,1])) 
#ax3.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax3.set_yticks([0,0.5,1.0])
ax3.set_title(r'$N_{at}=3$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax3.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax3.label_outer()

#Nat=4:  
ax4.plot(R17[:,0],R17[:,1], color = "k", linewidth = 2)
ax4.plot(K3[:,0],K3[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax4.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax4.set_xlim(-1,1)
ax4.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax4.set_ylim(0, 1.05*np.max(R17[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax4.set_yticks([0,0.5,1.0])
ax4.set_title(r'$N_{at}=4$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax4.label_outer()

#Nat=5:  
ax5.plot(R18[:,0],R18[:,1], color = "k", linewidth = 2)
ax5.plot(K4[:,0],K4[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax5.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
#ax5.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax5.set_xlim(-1,1)
ax5.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax5.set_ylim(0, 1.05*np.max(R18[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax5.set_yticks([0,0.5,1.0])
ax5.set_title(r'$N_{at}=5$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax5.label_outer()

#Nat=empty:  
#ax6.plot(R18[:,0],R18[:,1], color = "k", linewidth = 2)
#ax6.plot(K4[:,0],K4[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax6.set_xlabel("$\Delta_P/\kappa$",fontsize=13)
#ax6.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax6.set_xlim(-1.0,1.0)
ax6.set_xticks([-1,-0.5,0.0,0.5,1])
ax6.set_ylim(0, 1.05*np.max(R18[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax6.set_yticks([0,0.5,1.0])
#ax6.set_title(r'$N_{at}=5$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax6.label_outer()

fig.suptitle(r'Transmission spectrum EIT-Cavity for $N_{at}$ atoms with $g=5.0\kappa/\sqrt{N_{at}}$ and $\varepsilon=\sqrt{0.1}\kappa$',fontsize=15)
fig.savefig("EIT_transmission_Natall_g5_ep01_compare_QSC.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros com t_list diferentes

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(L1[:,0],L1[:,1], color = "k", linewidth = 1)
ax1.plot(L2[:,0], L2[:,1], color = "r", linestyle = "--", linewidth = 1)
ax1.plot(L3[:,0], L3[:,1], color = "blue", linestyle = "-.", linewidth = 1)
ax1.plot(L4[:,0], L4[:,1], color = "green", linestyle = ":", linewidth = 1)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend([r'MSC ($t=10000$ and $points=1000$)',r'MSC ($t=10000$ and $points=10000$)',r'MSC ($t=20000$)',r'MSC ($t=30000$)']) 
plt.title(r'Transmission spectrum for 2 atom: $\kappa=1.0$, $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-1,1)
plt.ylim(0, 1.05*np.max(L1[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat2_g10_ep01_compare_tlist.png",format='png', dpi=600)
plt.show()

# %%
#Integração em SC: comparando espectros com t_list diferentes

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(L5[:,0],L5[:,1], color = "k", linewidth = 1)
ax1.plot(L6[:,0], L6[:,1], color = "r", linestyle = "--", linewidth = 1)
ax1.plot(L7[:,0], L7[:,1], color = "blue", linestyle = "-.", linewidth = 1)
ax1.plot(L8[:,0], L8[:,1], color = "green", linestyle = ":", linewidth = 1)
ax1.plot(L9[:,0], L9[:,1], color = "yellow", linestyle = ":", linewidth = 1)
ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend([r'MSC ($t=2100$)',r'MSC ($t=5000$)',r'MSC ($t=8000$)',r'MSC ($t=10000$)',r'MSC ($t=20000$)']) 
plt.title(r'Transmission spectrum for 5 atoms: $\kappa=1.0$, $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-1,1)
plt.ylim(0, 1.05*np.max(L5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat5_g5_ep01_compare_tlist.png",format='png', dpi=600)
plt.show()

# %%
#MC: comparando espectros com t_list diferentes

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(R17[:,0], R17[:,1], color = "k", linewidth = 2)
ax1.plot(R19[:,0], R19[:,1], color = "r", linestyle = "--", linewidth = 1)

ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend([r'MC ($t=2100$)',r'MC ($t=5000$)']) 
plt.title(r'Transmission spectrum for 4 atoms: $\kappa=1.0$, $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-1,1)
plt.ylim(0, 1.05*np.max(L5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat4_g5_ep01_compare_tlist.png",format='png', dpi=600)
plt.show()

# %%
#MC: verificando se o resultado é muito ruidoso

fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.plot(R11[:,0], R11[:,1], color = "k", linewidth = 2)


ax1.set_xlabel("$\Delta_P/\kappa$")
ax1.set_ylabel("Normalized transmission")
ax1.legend([r'MC ($t=2100$)',r'MC ($t=5000$)']) 
plt.title(r'Transmission spectrum for 4 atoms: $\kappa=1.0$, $g=5.0/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
plt.xlim(-1,1)
plt.ylim(0, 1.05*np.max(L5[:,1])) 
plt.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
plt.yticks([0,0.5,1.0])
plt.savefig("EIT_transmission_Nat4_g5_ep01_compare_tlist.png",format='png', dpi=600)
plt.show()

# %%
#PLOT PARA ARTIGO: vary g_0, epsilon=sqrt{0.1}*kappa
fig, ((ax1), (ax2)) = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(1.5*3.54,1.5*3.54),
 gridspec_kw={'width_ratios': [1],'height_ratios': [1, 1],
                       'wspace': 0.4,
                       'hspace': 0.1},tight_layout=True)

#g=0.1: 
ax1.plot(F5[:,0],F5[:,1], color = "k", linewidth = 2.0)
#ax1.plot(T5[:,0], T5[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax1.set_xlabel("$\Delta_P/\kappa$")
#ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
#ax1.legend(["Quantum","Semiclassical"],frameon=False,fontsize=13) 
ax1.set_xlim(-5,5)
ax1.set_ylim(0, 1.05*np.max(T5[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax1.set_yticks([0,0.5,1.0])
#ax1.set_title(r'$g=0.1\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax1.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax1.label_outer()

#g=1.0: 
ax2.plot(F8[:,0],F8[:,1], color = "k", linewidth = 2)
#ax4.plot(T8[:,0], T8[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax2.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax2.set_xlim(-5,5)
ax2.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax2.set_ylim(0, 1.05*np.max(T8[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
#ax2.set_title(r'$g=1.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
#ax4.label_outer()
plt.text(-7., 0.29, 'Normalized transmission', fontsize=14, rotation='vertical')

plt.text(-16.8, 2.15, '(a)', fontsize=14)
plt.text(-16.8, 0.85, '(b)', fontsize=12)
plt.text(-4.8, 2.05, '(c)', fontsize=14)
plt.text(-4.8, 0.9, '(d)', fontsize=14)


#imagem (a): 
img_b = np.asarray(Image.open('/home/solakerino/Área de Trabalho/IC/Pôster/fig1b.jpeg'))
    # Define the position for the image axes [xaxis, yaxis, width, height]
ax1.image = fig.add_axes([-0.85, 0.4, 0.7, 0.7])
    # Display the image
ax1.image.imshow(img_b)
ax1.image.axis('off')

#imagem (b): 
img_a = np.asarray(Image.open('/home/solakerino/Área de Trabalho/IC/Pôster/fig1a.jpeg'))
    # Define the position for the image axes [xaxis, yaxis, width, height]
ax1.image = fig.add_axes([-0.7, 0.0, 0.5, 0.5])
    # Display the image
ax1.image.imshow(img_a)
ax1.image.axis('off')


#fig.suptitle(r'Transmission spectrum EIT-Cavity for 1 atom with $\varepsilon=\sqrt{0.1}\kappa$ and $\Omega_C=\kappa$',fontsize=18)
fig.savefig("EIT_transmission_Nat1_article.eps",format='eps', dpi=1200)#1200
plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_18510/3328029403.py:10: SyntaxWarning: invalid escape sequence '\D'
#   ax1.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_18510/3328029403.py:24: SyntaxWarning: invalid escape sequence '\D'
#   ax2.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
# /tmp/ipykernel_18510/3328029403.py:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.savefig("EIT_transmission_Nat1_article.eps",format='eps', dpi=1200)#1200
# /home/solakerino/miniconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#NOVO -> PLOT PARA ARTIGO: vary g_0, epsilon=sqrt{0.1}*kappa
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True,figsize=(3*3.54,1.0*4.54))#3*3.54,1.0*4.0


#g=0.1: 
ax2.plot(F5[:,0],F5[:,1], color = "k", linewidth = 2.0)
ax2.plot(T5[:,0], T5[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax2.set_xlabel("$\Delta_P/\kappa$")
#ax1.set_ylabel(r'Normalized \\ \hspace{1.0cm} transmission',fontsize=13)
ax2.legend(["Quantum","Semiclassical"],frameon=False,fontsize=13) 
ax2.set_xlim(-5,5)
ax2.set_ylim(0, 1.05*np.max(T5[:,1])) 
#ax1.axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax2.set_yticks([0,0.5,1.0])
ax2.set_title(r'$g=0.1\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)
ax2.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax2.label_outer()

#imagem (a): 
img_a = np.asarray(Image.open('/home/solakerino/Área de Trabalho/IC/Pôster/fig1a.jpeg'))
    # Define the position for the image axes [xaxis, yaxis, width, height]
ax1.image = fig.add_axes([0.3, 0.6, 0.15, 0.15])
    # Display the image
ax1.image.imshow(img_a)
ax1.image.axis('off')


#imagem (b):
img_b = np.asarray(Image.open('/home/solakerino/Área de Trabalho/IC/Pôster/fig1b.jpeg'))
    # Define the position for the image axes [xaxis, yaxis, width, height]
ax3.image = fig.add_axes([0.3, 0.6, 0.15, 0.15])
    # Display the image
ax3.image.imshow(img_a)
ax3.image.axis('off')


#g=1.0: 
ax4.plot(F8[:,0],F8[:,1], color = "k", linewidth = 2)
ax4.plot(T8[:,0], T8[:,1], color = "r", linestyle = "--", linewidth = 1.5)
ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)
#ax4.set_ylabel("Normalized transmission")
#ax4.legend(["Quantum","Semiclassical"],frameon=False) 
#ax4.title(r'Transmission spectrum for 1 atom: $\kappa=1.0$, $g=0.1/\sqrt{N_{at}}\cdot\kappa$ and $\varepsilon=\sqrt{0.1}\cdot\kappa$', fontsize=18)
ax4.set_xlim(-5,5)
ax4.set_xticks([-5.0,-2.5,0.0,2.5,5.0])
ax4.set_ylim(0, 1.05*np.max(T8[:,1])) 
#ax4.set_axhline(y=0.5, xmin=-10.0, xmax=10.0, color="purple", linestyle = ':')
ax4.set_yticks([0,0.5,1.0])
ax4.set_title(r'$g=1.0\kappa$', y=0.9,x=0.15, pad=-15, fontsize=13)

#fig.suptitle(r'Transmission spectrum EIT-Cavity for 1 atom with $\varepsilon=\sqrt{0.1}\kappa$ and $\Omega_C=\kappa$',fontsize=18)
fig.savefig("EIT_transmission_Nat1_article.png",format='png', dpi=1200)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:40: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:40: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_26732/2801818784.py:8: SyntaxWarning: invalid escape sequence '\D'
#   ax2.set_xlabel("$\Delta_P/\kappa$")
# /tmp/ipykernel_26732/2801818784.py:40: SyntaxWarning: invalid escape sequence '\D'
#   ax4.set_xlabel('$\Delta_P / \kappa$',fontsize=13)

# %%
img = np.asarray(Image.open('/home/solakerino/Área de Trabalho/IC/Pôster/fig1a.jpeg'))
#print(repr(img))
imgplot = plt.imshow(img)


fig1a = image.imread('/home/solakerino/Área de Trabalho/IC/Pôster/fig1a.jpeg')
ax_image.axis('off')
plt.imshow(fig1a)

# Define the position and size parameters
image_xaxis = 0.3
image_yaxis = 0.6
image_width = 0.15
image_height = 0.15  # Same as width since our logo is a square

# Define the position for the image axes
ax_image = fig.add_axes([image_xaxis,
                         image_yaxis,
                         image_width,
                         image_height]
                       )

# Display the image
ax_image.imshow(image)
ax_image.axis('off')  # Remove axis of the image

#imagebox = OffsetImage(fig1a, zoom = 0.15, frameon = False)

#ab = AnnotationBbox(imagebox, (5, 700), frameon = False)
#ax.add_artist(ab)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       3 imgplot = plt.imshow(img)
#       6 fig1a = image.imread('/home/solakerino/Área de Trabalho/IC/Pôster/fig1a.jpeg')
# ----> 7 ax_image.axis('off')
#       8 plt.imshow(fig1a)
#      11 #imagebox = OffsetImage(fig1a, zoom = 0.15, frameon = False)
#      12
#      13 #ab = AnnotationBbox(imagebox, (5, 700), frameon = False)
#      14 #ax.add_artist(ab)
#
# NameError: name 'ax_image' is not defined
